# %%
from src.utils.plotter import Plotter
import pandas as pd 

comp_res: pd.DataFrame = pd.read_excel("../docs/ESTIMATOR_COMP_METRICS.xlsx", sheet_name="Sheet2")

plotter = Plotter(list(range(0, len(comp_res["Events/s"]))), title="Events/s")

plotter.add_subplot([("Events/s", comp_res["Events/s"])])
print(comp_res["Events/s"].mean(), comp_res["Events/s"].std())
plotter.plot()
# Out:
# 8962.138446997335 1166.1878814016804
